# %% [markdown]
# # 4 MODIS Aerosol Product - Level 2

# %% [markdown]
# ### About

# %% [markdown]
# This module shows the structure of the `MODIS Aerosol Product` nd what information of the data files can be used in order to load, browse and visualize aerosol optical thickness.
#
# According to [NASA](https://ladsweb.modaps.eosdis.nasa.gov/missions-and-measurements/science-domain/aerosol/), "The MODIS Aerosol Product monitors the ambient aerosol optical thickness over the oceans globally and over the continents. Furthermore, the aerosol size distribution is derived over the oceans, and the aerosol type is derived over the continents. 'Fine' aerosols (anthropogenic/pollution) and 'coarse' aerosols (natural particles; e.g., dust) are also derived."
#
# "There are two MODIS Aerosol data product files: MOD04_L2, containing data collected from the Terra platform (2000 onwards); and MYD04_L2, containing data collected from the Aqua platform (2002 onwards). Granule-level (Level 2) data are produced at a horizontal pixel size (at nadir) of 10 km x 10 km. The Dark Target Land and Ocean products are additionally provided at a horizontal pixel size (at nadir) of 3 km x 3 km within the MOD04_3K and MYD04_3K files for Terra and Aqua respectively." [(Source)](https://atmosphere-imager.gsfc.nasa.gov/products/aerosol)

# %% [markdown]
# ### Basic Facts

# %% [markdown]
# > **Spatial resolution**: `10 km x 10 km at nadir`<br>
# > **Spatial coverage**: `Global` <br>
# > **Data availability**: `since 2000`

# %% [markdown]
# ### How to access the data

# %% [markdown]
# This notebook uses the MODIS MOD04_L2 dataset from the Terra platform. This data can be ordered via the [LAADS DAAC](https://ladsweb.modaps.eosdis.nasa.gov/search/order/2/MOD04_L2--61) and are distributed in `HDF4-EOS` format, which is based on `HDF4`.
#
# You need to [register for an Earthdata account](https://urs.earthdata.nasa.gov/) in order to be able to download data.

# %% [markdown]
# ### Module outline
# - [1 - Load and browse MODIS MOD04 Level 2 data](#modis_load)
# - [2 - Visualize MODIS MOD04 Level 2 data](#visualize_modis_aerosol)

# %% [markdown]
# <hr>

# %% [markdown]
# #### Load required libraries

# %%
import sys
# !{sys.executable} -m pip install cartopy netCDF4 h5netcdf==1.3.0 satpy==0.51.0 pyhdf h5py python-geotiepoints
# Out:
# Requirement already satisfied: cartopy in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (0.25.0)
# Requirement already satisfied: netCDF4 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: h5netcdf==1.3.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: satpy==0.51.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (0.51.0)
# Requirement already satisfied: pyhdf in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (0.11.6)
# Requirement already satisfied: h5py in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (3.14.0)
# Requirement already satisfied: python-geotiepoints in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from h5netcdf==1.3.0) (25.0)
# Requirement already satisfied: dask>=0.17.1 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from dask[array]>=0.17.1->satpy==0.51.0) (2025.9.1)
# Requirement already satisfied: donfig in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (0.8.1.post1)
# Requirement already satisfied: numpy>=1.21 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (2.3.3)
# Requirement already satisfied: pillow in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (11.3.0)
# Requirement already satisfied: platformdirs in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (4.4.0)
# Requirement already satisfied: pooch in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (1.8.2)
# Requirement already satisfied: pykdtree in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (1.4.3)
# Requirement already satisfied: pyorbital in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (1.10.2)
# Requirement already satisfied: pyproj>=2.2 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (3.7.2)
# Requirement already satisfied: pyresample>=1.24.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (1.34.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (6.0.3)
# Requirement already satisfied: trollimage>=1.24 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (1.27.0)
# Requirement already satisfied: trollsift in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (0.6.0)
# Requirement already satisfied: xarray>=0.14.1 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (2025.9.1)
# Requirement already satisfied: zarr in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from satpy==0.51.0) (3.1.3)
# Requirement already satisfied: matplotlib>=3.6 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from cartopy) (3.10.6)
# Requirement already satisfied: shapely>=2.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from cartopy) (2.1.2)
# Requirement already satisfied: pyshp>=2.3 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from cartopy) (3.0.1)
# Requirement already satisfied: cftime in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from netCDF4) (1.6.4)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from netCDF4) (2025.10.5)
# Requirement already satisfied: scipy in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from python-geotiepoints) (1.16.2)
# Requirement already satisfied: pandas in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from python-geotiepoints) (2.3.3)
# Requirement already satisfied: click>=8.1 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy==0.51.0) (8.3.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy==0.51.0) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy==0.51.0) (2025.9.0)
# Requirement already satisfied: partd>=1.4.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy==0.51.0) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy==0.51.0) (1.0.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy==0.51.0) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask>=0.17.1->dask[array]>=0.17.1->satpy==0.51.0) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: locket in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from partd>=1.4.0->dask>=0.17.1->dask[array]>=0.17.1->satpy==0.51.0) (1.0.0)
# Requirement already satisfied: configobj in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from pyresample>=1.24.0->satpy==0.51.0) (5.0.9)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from pandas->python-geotiepoints) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from pandas->python-geotiepoints) (2025.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from pooch->satpy==0.51.0) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from requests>=2.19.0->pooch->satpy==0.51.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from requests>=2.19.0->pooch->satpy==0.51.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from requests>=2.19.0->pooch->satpy==0.51.0) (2.5.0)
# Requirement already satisfied: defusedxml in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from pyorbital->satpy==0.51.0) (0.7.1)
# Requirement already satisfied: numcodecs>=0.14 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr->satpy==0.51.0) (0.16.1)
# Requirement already satisfied: typing-extensions>=4.9 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from zarr->satpy==0.51.0) (4.15.0)
# Requirement already satisfied: crc32c>=2.7 in /opt/miniconda3/envs/cwcc/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr->satpy==0.51.0) (2.7.1)

# %%
from pyhdf.SD import SD, SDC
import numpy as np

import os
os.environ['PROJ_LIB'] = '/opt/conda/share/proj'

import matplotlib.pyplot as plt
import matplotlib.colors
from matplotlib.axes import Axes

import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.mpl.geoaxes import GeoAxes
GeoAxes._pcolormesh_patched = Axes.pcolormesh

import pyresample as prs

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action = "ignore", category = RuntimeWarning)

# %% [markdown]
# #### Load helper functions

# %%
if os.path.exists("functions.ipynb"):
    # %run functions.ipynb
elif os.path.exists("../functions.ipynb"):
    # %run ../functions.ipynb
else:
    print("Helper functions notebook not found in any specified path. Downloading from Gitlab.")    
    # !wget https://gitlab.eumetsat.int/eumetlab/atmosphere/atmosphere/-/raw/master/functions.ipynb
    # %run functions.ipynb

# %%
if os.path.exists("bucket_functions.ipynb"):
    # %run bucket_functions.ipynb
elif os.path.exists("../bucket_functions.ipynb"):
    # %run ../bucket_functions.ipynb
else:
    print("Helper functions notebook not found in any specified path. Downloading from Gitlab.")    
    # !wget https://gitlab.eumetsat.int/eumetlab/atmosphere/atmosphere/-/raw/master/90_workshops/202410_wmo_school/bucket_functions.ipynb
    # %run bucket_functions.ipynb

# %%
base_url = 'https://s3.waw3-2.cloudferro.com/swift/v1/wmo/'
all_paths_list = list_data_on_bucket(base_url)

all_directories_list = [os.path.dirname(path) for path in all_paths_list if path.count('/') <= 4]
# Take unique directories
all_directories_list = list(np.unique(all_directories_list))
all_directories_list
# Out:
# Status ok
# [np.str_('eodata'),
#  np.str_('eodata/fci'),
#  np.str_('eodata/fci/W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-FDHSI-FD--x-x---x_C_EUMT_20240924092245_IDPFI_OPE_20240924092007_20240924092928_N__C_0057_0000'),
#  np.str_('eodata/gome2'),
#  np.str_('eodata/gome2/aai'),
#  np.str_('eodata/gome2/hcho'),
#  np.str_('eodata/gome2/hcho/daily'),
#  np.str_('eodata/gome2/no2'),
#  np.str_('eodata/gome2/no2/daily'),
#  np.str_('eodata/iasi'),
#  np.str_('eodata/iasi/co'),
#  np.str_('eodata/iasi/nh3'),
#  np.str_('eodata/meteosat'),
#  np.str_('eodata/meteosat/2020'),
#  np.str_('eodata/meteosat/2024'),
#  np.str_('eodata/modis'),
#  np.str_('eodata/modis/10km'),
#  np.str_('eodata/modis/level_1b'),
#  np.str_('eodata/monarch'),
#  np.str_('eodata/pmap'),
#  np.str_('eodata/s3'),
#  np.str_('eodata/s3/aod'),
#  np.str_('eodata/s3/aod/S3A_SL_2_AOD____20240821T082340_20240821T082839_20240821T101507_0299_116_078______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/aod/S3A_SL_2_AOD____20240825T081954_20240825T082453_20240825T101112_0299_116_135______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/aod/S3A_SL_2_AOD____20240827T090833_20240827T091332_20240827T105910_0299_116_164______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/aod/S3B_SL_2_AOD____20240822T071826_20240822T072325_20240822T091012_0299_096_334______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/aod/S3B_SL_2_AOD____20240823T083336_20240823T083833_20240823T102404_0299_096_349______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/aod/S3B_SL_2_AOD____20240826T071443_20240826T071941_20240826T090552_0299_097_006______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/aod/S3B_SL_2_AOD____20240828T080336_20240828T080834_20240828T095539_0299_097_035______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp'),
#  np.str_('eodata/s3/frp/S3A_SL_2_FRP____20240821T083339_20240821T083839_20240821T101449_0299_116_078______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3A_SL_2_FRP____20240822T075721_20240822T080221_20240822T094822_0299_116_092______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3A_SL_2_FRP____20240823T073602_20240823T074102_20240823T092358_0299_116_106______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3A_SL_2_FRP____20240825T205043_20240825T205543_20240825T215041_0299_116_142______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3A_SL_2_FRP____20240826T075336_20240826T075836_20240826T094602_0299_116_149______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3A_SL_2_FRP____20240827T073216_20240827T073716_20240827T091808_0299_116_163______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3A_SL_2_FRP____20240828T084223_20240828T084723_20240828T103231_0299_116_178______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3B_SL_2_FRP____20240821T074944_20240821T075444_20240821T093653_0299_096_320______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3B_SL_2_FRP____20240822T085945_20240822T090445_20240822T104910_0299_096_335______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3B_SL_2_FRP____20240824T081218_20240824T081718_20240824T095822_0299_096_363______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3B_SL_2_FRP____20240825T201712_20240825T202212_20240825T211234_0299_096_384______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3B_SL_2_FRP____20240826T085603_20240826T090103_20240826T104512_0299_097_007______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3B_SL_2_FRP____20240828T080334_20240828T080834_20240828T095432_0299_097_035______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s3/frp/S3B_SL_2_FRP____20240828T080834_20240828T081334_20240828T095433_0299_097_035______MAR_O_NR_003.SEN3'),
#  np.str_('eodata/s5p'),
#  np.str_('eodata/s5p/aer_ai/S5P_OFFL_L2__AER_AI_20200619T130926_20200619T145056_13906_01_010302_20200621T025709'),
#  np.str_('eodata/s5p/aer_ai/S5P_OFFL_L2__AER_AI_20200814T121536_20200814T135706_14700_01_010302_20200817T053635'),
#  np.str_('eodata/s5p/aer_ai/S5P_OFFL_L2__AER_AI_20200814T135706_20200814T153835_14701_01_010302_20200817T053700'),
#  np.str_('eodata/s5p/aer_ai/S5P_OFFL_L2__AER_AI_20200815T101459_20200815T115629_14713_01_010302_20200818T074244'),
#  np.str_('eodata/s5p/aer_ai/S5P_OFFL_L2__AER_AI_20200815T115629_20200815T133758_14714_01_010302_20200818T074310'),
#  np.str_('eodata/s5p/aer_ai/S5P_OFFL_L2__AER_AI_20200817T125943_20200817T144113_14743_01_010302_20200820T045459'),
#  np.str_('eodata/s5p/aer_ai/S5P_OFFL_L2__AER_AI_20200818T105906_20200818T124036_14756_01_010302_20200821T073142'),
#  np.str_('eodata/s5p/aer_ai/S5P_OFFL_L2__AER_AI_20200818T124036_20200818T142205_14757_01_010302_20200821T073243'),
#  np.str_('eodata/s5p/aer_ai/S5P_OFFL_L2__AER_AI_20200818T142205_20200818T160334_14758_01_010302_20200821T073403'),
#  np.str_('eodata/s5p/aer_ai/S5P_RPRO_L2__AER_AI_20200814T103407_20200814T121536_14699_03_020400_20221027T131357'),
#  np.str_('eodata/s5p/aer_ai/S5P_RPRO_L2__AER_AI_20200815T133758_20200815T151928_14715_03_020400_20221027T132512'),
#  np.str_('eodata/s5p/aer_ai/S5P_RPRO_L2__AER_AI_20200816T113721_20200816T131851_14728_03_020400_20221027T132558'),
#  np.str_('eodata/s5p/aer_ai/S5P_RPRO_L2__AER_AI_20200816T131851_20200816T150020_14729_03_020400_20221027T133635'),
#  np.str_('eodata/s5p/aer_ai/S5P_RPRO_L2__AER_AI_20200816T150020_20200816T164149_14730_03_020400_20221027T133639'),
#  np.str_('eodata/s5p/aer_ai/S5P_RPRO_L2__AER_AI_20200817T111814_20200817T125943_14742_03_020400_20221027T133721'),
#  np.str_('eodata/s5p/aer_ai/S5P_RPRO_L2__AER_AI_20200817T144113_20200817T162242_14744_03_020400_20221027T134748'),
#  np.str_('eodata/s5p/aer_ai/S5P_RPRO_L2__AER_AI_20200819T103958_20200819T122128_14770_03_020400_20221027T140000'),
#  np.str_('eodata/s5p/co')]

# %% [markdown]
# #### Set geographical extent

# %%
latmin = 0
latmax = 40
lonmin = -50
lonmax = 20

# %% [markdown]
# <hr>

# %% [markdown]
# ## <a id='modis_load'></a>1. Load and browse MODIS Aerosol Product data

# %% [markdown]
# We will use the Python library `pyhdf` to open a HDF4 data file from 19th June 2020. Read more about `pyhdf` [here](https://github.com/fhs/pyhdf).
#
# Unfortunately,`pyhdf` cannot directly open files from an object storage service without first downloading the files locally. `pyhdf` expects local file paths to work with, as it reads files from disk.

# %% [markdown]
# ### Inspect the structure of one MODIS MOD04 data file

# %% [markdown]
# The data is from 19 June 2020 and is stored in the current folder. You can use the function `SD(file_name, SDC.READ)` to load one single file to better understand the data structure. The results in a `SD`, which stands for Scientific Dataset.

# %%
download_directory = "../../downloads/"

data_path = base_url + 'eodata/modis/10km/MOD04_L2.A2020171.1110.061.2020171193845.hdf'
response = requests.get(data_path, stream=True)

if response.status_code == 200:
    # Determine the file name from the path or create one
    file_name = os.path.join(download_directory, data_path.split("/")[-1])

    # Open the file in write mode and save the streamed content
    with open(file_name, 'wb') as f:
        for chunk in response.iter_content(chunk_size=8192):
            if chunk:  # Filter out keep-alive new chunks
                f.write(chunk)

    print(f"Downloaded file: {file_name}")

    hdf = SD(file_name, SDC.READ)
    print(hdf)
else:
    print(f"Failed to fetch file: {response.status_code}")
# Out:
# Downloaded file: ../../downloads/MOD04_L2.A2020171.1110.061.2020171193845.hdf
# <pyhdf.SD.SD object at 0x16dbf6b90>

# %% [markdown]
# <br>

# %% [markdown]
# Next we specify `Optical_Depth_Land_And_Ocean` as the dataset name that we are interested in. This variable shows optical depth retrievals for land and ocean reported only at 0.55 microns and only for high quality retrievals. The minimum value is -0.10 and maximum value is 5.00.
#
# We can use the `.select()` method to select this dataset from the HDF4 file. Next, this data is read in as a 2-D array with type `double`.

# %%
dataset_name = 'Optical_Depth_Land_And_Ocean'

# Read dataset
data2D = hdf.select(dataset_name)
data = data2D[:,:].astype(np.double)

data
# Out:
# array([[   60.,    65., -9999., ..., -9999., -9999., -9999.],
#        [   57.,    64.,   160., ..., -9999., -9999., -9999.],
#        [-9999.,    58.,    98., ..., -9999., -9999., -9999.],
#        ...,
#        [ 2260.,  2367.,  2501., ..., -9999., -9999., -9999.],
#        [ 2226.,  2324.,  2426., ..., -9999., -9999., -9999.],
#        [ 2218.,  2388.,  2282., ..., -9999., -9999., -9999.]],
#       shape=(203, 135))

# %% [markdown]
# <br>

# %% [markdown]
# We can then also select the latitude and longitude datasets for plotting later on. We store each of these as 2D-arrays separately in variables called `longitude` or `latitude` respectively. We will print the `latitude` array so you can see what it looks like.

# %%
# Read geolocation dataset.
lat = hdf.select('Latitude')
latitude = lat[:,:]
lon = hdf.select('Longitude')
longitude = lon[:,:]

latitude
# Out:
# array([[29.96747 , 29.940516, 29.913933, ..., 26.851688, 26.76215 ,
#         26.666471],
#        [29.879114, 29.852064, 29.825397, ..., 26.765076, 26.67547 ,
#         26.579945],
#        [29.790695, 29.76356 , 29.73682 , ..., 26.679556, 26.590334,
#         26.49422 ],
#        ...,
#        [12.29073 , 12.245614, 12.203038, ...,  9.441682,  9.377637,
#          9.30909 ],
#        [12.202265, 12.15706 , 12.11441 , ...,  9.353609,  9.289703,
#          9.221207],
#        [12.114191, 12.068885, 12.026138, ...,  9.265935,  9.202284,
#          9.133934]], shape=(203, 135), dtype=float32)

# %% [markdown]
# <br>

# %% [markdown]
# Finally, we need to retrieve attributes from the dataset for plotting purposes. The first step is to store the global attributes dictionary from the dataset as a variable called `attrs`.

# %%
# Retrieve attributes.
attrs = data2D.attributes(full=1)
attrs
# Out:
# {'valid_range': ([-100, 5000], 0, 22, 2),
#  '_FillValue': (-9999, 1, 22, 1),
#  'long_name': ('AOT at 0.55 micron for both ocean (Average) (Quality flag=1,2,3) and land (corrected) (Quality flag=3)',
#   2,
#   4,
#   102),
#  'units': ('None', 3, 4, 4),
#  'scale_factor': (0.0010000000474974513, 4, 6, 1),
#  'add_offset': (0.0, 5, 6, 1),
#  'Parameter_Type': ('Output', 6, 4, 6),
#  'Cell_Along_Swath_Sampling': ([1, 2021, 10], 7, 24, 3),
#  'Cell_Across_Swath_Sampling': ([1, 1354, 10], 8, 24, 3),
#  'Geolocation_Pointer': ('Internal geolocation arrays', 9, 4, 27)}

# %% [markdown]
# <br>

# %% [markdown]
# The attributes dictionary includes a few useful attributes including `long_name`, `add_offset`, `_FillValue`, `scale_factor`, and `units`. For each of these, we are interested only in the first element of the key. Let us define variables for these for use in visualizing the data later.

# %%
lname=attrs["long_name"]
long_name= lname[0]

aoa=attrs["add_offset"]
add_offset = aoa[0]

fva=attrs["_FillValue"]
_FillValue = fva[0]

sfa=attrs["scale_factor"]
scale_factor = sfa[0]        

ua=attrs["units"]
units = ua[0]

# %% [markdown]
# <br>

# %% [markdown]
# Next, let's replace all data which has the value of `-9999`, which is the fill value, with `nan` which stands for "Not a Number".

# %%
data[data == _FillValue] = np.nan

# %% [markdown]
# <br>

# %% [markdown]
# Finally, we do a calculation which subtracts the value of `add_offset` from the data, before multiplying the result by the `scale_factor` in order to get the actual value of the data.

# %%
data = (data - add_offset) * scale_factor

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id='visualize_modis_aerosol'></a>2. Visualize MODIS MOD04 Level 2 data

# %% [markdown]
# ### <a id='visualize'></a>Visualize *Optical_Depth_Land_And_Ocean* over the Mediterranean

# %% [markdown]
# The next step is to visualize the dataset. You can use the function [visualize_pcolormesh](../../functions.ipynb#visualize_pcolormesh), which makes use of matploblib's function `pcolormesh` and the [Cartopy](https://scitools.org.uk/cartopy/docs/latest/) library.
#
# With `?visualize_pcolormesh` you can open the function's docstring to see what keyword arguments are needed to prepare your plot.

# %%
# ?visualize_pcolormesh
# Out:
# Signature:
# visualize_pcolormesh(
#     data_array,
#     longitude,
#     latitude,
#     projection,
#     color_scale,
#     unit,
#     long_name,
#     vmin,
#     vmax,
#     set_global=True,
#     lonmin=-180,
#     lonmax=180,
#     latmin=-90,
#     latmax=90,
# )
# Docstring:
# Visualizes a xarray.DataArray with matplotlib's pcolormesh function.
#
# Parameters:
#     data_array(xarray.DataArray): xarray.DataArray holding the data values
#     longitude(xarray.DataArray): xarray.DataArray holding the longitude values
#     latitude(xarray.DataArray): xarray.DataArray holding the latitude values
#     projection(str): a projection provided by the cartopy library, e.g. ccrs.PlateCarree()
#     color_scale(str): string taken from matplotlib's color ramp reference
#     unit(str): the unit of the parameter, taken from the NetCDF file if possible
#     long_name(str): long name of the parameter, taken from the NetCDF file if possible
#     vmin(int): minimum number on visualisation legend
#     vmax(int): maximum number on visualisation legend
#     set_global(boolean): optional kwarg, default is True
#     lonmin,lonmax,latmin,latmax(float): optional kwarg, set geographic extent is set_global kwarg is set to
#                                         False
# File:      /var/folders/49/4n_jx67x5gg0fw4kkd3zb_wm0000gn/T/ipykernel_18105/2163691773.py
# Type:      function

# %% [markdown]
# You can make use of the variables we have defined above:
# - `long_name`
# - `latitude`
# - `longitude`
# - `units`
#
# Additionally, you can specify the color scale and minimum and maximum data values.

# %% [markdown]
# Define the bounding box information

# %%
visualize_pcolormesh(data_array=data,
                     longitude=longitude,
                     latitude=latitude,
                     projection=ccrs.PlateCarree(),
                     color_scale='afmhot_r',
                     unit=units,
                     long_name=long_name + "\n 19 June 2020",
                     vmin=0, 
                     vmax=4,
                     lonmin=lonmin,
                     lonmax=lonmax,
                     latmin=latmin,
                     latmax=latmax,
                     set_global=False)
# Out:
# (<Figure size 2000x1000 with 2 Axes>,
#  <GeoAxes: title={'center': 'AOT at 0.55 micron for both ocean (Average) (Quality flag=1,2,3) and land (corrected) (Quality flag=3)\n 19 June 2020'}>)

# %% [markdown]
# <hr>

# %% [markdown]
# ### References
# * Levy, R., Hsu, C., et al., 2015. MODIS Atmosphere L2 Aerosol Product. NASA MODIS Adaptive Processing System, Goddard Space Flight Center, USA: http://dx.doi.org/10.5067/MODIS/MOD04_L2.061
#
# * This notebook was adapted from: https://dustbook.ltpy.adamplatform.eu/docs/modis_aerosol.html

# %% [markdown]
# <hr>

# %% [markdown]
# <img src='../img/copernicus_logo.png' alt='Logo EU Copernicus' align='right' width='20%'><br><br><br><br>
#
# <p style="text-align:right;">This project is licensed under <a href="../../LICENSE">GNU General Public License v3.0 only</a> and is developed under a Copernicus contract.

# %% [markdown]
# <p style="text-align:right;"> <a href='https://training.eumetsat.int'>EUMETSAT Training</a> | <a href='mailto:training@eumetsat.int'>Contact the training team</a></p>
